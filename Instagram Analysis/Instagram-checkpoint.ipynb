# %% [markdown]
# # Instagram Reach Analysis

# %%
# First install all

#!pip install wordcloud
#!pip install scikit-learn
#!pip install statsmodels

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from sklearn.model_selection import train_test_split
from sklearn.linear_model import PassiveAggressiveRegressor
import warnings as wr
wr.filterwarnings('ignore')

# %%
df = pd.read_csv("Instagram.csv", encoding ='latin1')
df.head()
# Out:
#    Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0         3920       2586           1028           619          56     98
# 1         5394       2727           1838          1174          78    194
# 2         4021       2085           1188             0         533     41
# 3         4528       2700            621           932          73    172
# 4         2518       1704            255           279          37     96
#
#    Comments  Shares  Likes  Profile Visits  Follows  \
# 0         9       5    162              35        2
# 1         7      14    224              48       10
# 2        11       1    131              62       12
# 3        10       7    213              23        8
# 4         5       4    123               8        0
#
#                                              Caption  \
# 0  Here are some of the most important data visua...
# 1  Here are some of the best data science project...
# ...

# %%
# Before starting everything, let’s have a look at whether this dataset contains any null values or not
df.isnull().sum()
# Out:
# Impressions       0
# From Home         0
# From Hashtags     0
# From Explore      0
# From Other        0
# Saves             0
# Comments          0
# Shares            0
# Likes             0
# Profile Visits    0
# Follows           0
# Caption           0
# Hashtags          0
# dtype: int64

# %%
# If it has a null value in every column. Let’s drop all these null values and move further:
df = df.dropna()

# %%
# Let’s have a look at the insights of the columns to understand the data type of all the columns:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Impressions     119 non-null    int64
#  1   From Home       119 non-null    int64
#  2   From Hashtags   119 non-null    int64
#  3   From Explore    119 non-null    int64
#  4   From Other      119 non-null    int64
#  5   Saves           119 non-null    int64
#  6   Comments        119 non-null    int64
#  7   Shares          119 non-null    int64
#  8   Likes           119 non-null    int64
#  9   Profile Visits  119 non-null    int64
#  10  Follows         119 non-null    int64
#  11  Caption         119 non-null    object
#  12  Hashtags        119 non-null    object
# dtypes: int64(11), object(2)
# memory usage: 12.2+ KB

# %% [markdown]
# # Distribution Analysis of Home Page Impressions

# %%
plt.figure(figsize=(10,8))

plt.style.use("fivethirtyeight")
plt.title("Distribution of Impressions From Home")
sns.distplot(df['From Home'])
plt.show()

# %% [markdown]
# # Distribution Analysis of Impressions Generated Through Hashtags

# %%
plt.figure(figsize=(10,8))

plt.title("Distribution of Impressions From Hashtags")
sns.distplot(df['From Hashtags'])

plt.show()

# %% [markdown]
# # Distribution Analysis of Impressions Generated Through the Explore Page

# %%
plt.figure(figsize =(10,8))

plt.title("Distribution of Impressions From Explore")
sns.distplot(df['From Explore'])
plt.show()

# %% [markdown]
# # Source-Wise Impressions

# %%
home = df["From Home"].sum()
hashtags = df["From Hashtags"].sum()
explore = df["From Explore"].sum()
other = df["From Other"].sum()

labels =['From Home', 'From Hashtags', 'From Explore', 'Other']
values = [home, hashtags, explore, other]

fig = px.pie(df, values=values, names=labels, title="Impression on Instagram Posts From Various Sources", hole = 0.5)
fig.show()

# %% [markdown]
# # Caption Word Cloud

# %%
# Let’s create a word cloud of the caption column to look at the most used words in the caption of my Instagram posts
text =" ".join(i for i in df.Caption)
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords, background_color = "white").generate(text)
plt.style.use('classic')
plt.figure(figsize=(12,10))
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # Relationship Between Likes and Impressions

# %%
figure = px.scatter(data_frame = df, x ='Impressions', y = 'Likes', size = 'Likes', trendline = 'ols',
                    title = "Relationship Between Likes and Impressions")

figure.show()

# %% [markdown]
# # Relationship Between Comments and Impressions

# %%
figure = px.scatter(data_frame = df, x = "Impressions", y = "Comments", size = "Comments", trendline = "ols", 
                    title = "Relationship Between Comments and Total Impressions")
figure.show()

# %% [markdown]
# # Relationship Between Shares and Impressions

# %%
figure = px.scatter(data_frame = df, x = "Impressions", y = "Shares", size = "Shares", trendline = "ols",
                    title = "Relationship Between Shares and Total Impressions")
figure.show()

# %% [markdown]
# # Relationship Between Post Saves and Impressions

# %%
figure = px.scatter(data_frame = df, x = "Impressions", y = "Saves", size = "Saves", trendline = "ols", 
                    title = "Relationship Between Post Saves and Total Impressions")
figure.show()

# %% [markdown]
# # Correlation Sorting

# %%
correlation = df.select_dtypes(include='number').corr()
print(correlation["Impressions"].sort_values(ascending = False))
# Out:
# Impressions       1.000000
# From Explore      0.893607
# Follows           0.889363
# Likes             0.849835
# From Home         0.844698
# Saves             0.779231
# Profile Visits    0.760981
# Shares            0.634675
# From Other        0.592960
# From Hashtags     0.560760
# Comments         -0.028524
# Name: Impressions, dtype: float64

# %% [markdown]
# # Correlation Heatmap

# %%
correlation = df.select_dtypes(include='number').corr()

plt.figure(figsize = (10,8))
sns.heatmap(correlation, annot = True, cmap = 'coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# # Correlation with Impressions

# %%
correlation = df.select_dtypes(include='number').corr()

correlation["Impressions"].sort_values(ascending = False).plot( kind = 'bar', figsize = (10,5) )

plt.title("Correlation with Impressions")
plt.ylabel("Correlation")
plt.show()

# %% [markdown]
# # Let's Find Conversion_Rate

# %%
conversion_rate = (df["Follows"].sum()/ df["Profile Visits"].sum()) * 100
print(conversion_rate)
# Out:
# 41.00265604249668

# %% [markdown]
# # Follow Conversion Rate

# %%
conversion_rate = (df["Follows"].sum() / df["Profile Visits"].sum()) * 100

plt.pie(
    [conversion_rate, 100-conversion_rate],
    labels=["Followed", "Not Followed"],
    autopct="%1.1f%%"
)

plt.title("Profile Visit Conversion Rate")
plt.show()

# %%
# Let’s have a look at the relationship between the total profile visits and the number of followers gained from all profile visits:

figure = px.scatter(data_frame = df, x = "Profile Visits", y = "Follows", size = "Follows", trendline = "ols", 
                    title = "Relationship Between Profile Visits and Followers Gained")
figure.show()

# %% [markdown]
# # Likes vs Saves

# %%
fig = px.scatter(df, x = "Likes", y ="Saves", size ="Impressions", trendline="ols",
                 title = "Relationship Between Likes and Saves")
fig.show()

# %% [markdown]
# # Comments vs Saves

# %%
fig = px.scatter(df, x = "Comments", y = "Saves", size ="Impressions", trendline = "ols",
                 title = "Relationship Between Comments and Saves")
fig.show()

# %% [markdown]
# # Shares vs Saves

# %%
fig = px.scatter(df, x = "Shares", y ="Saves", size = "Impressions", trendline = "ols",
                 title = "Relationship Between Shares and Saves")
fig.show()

# %% [markdown]
# # Top 10 Posts by Likes

# %%
top_posts = df.nlargest(10, "Likes")

plt.figure(figsize = [10,5])
plt.bar(range(len(top_posts)), top_posts["Likes"])

plt.title("Top 10 Posts by Likes")
plt.xlabel("Post Rank")
plt.ylabel("Likes")
plt.show()

# %% [markdown]
# # Average Engagement Metrics

# %%
metrics = ["Likes", "Comments", "Shares", "Saves"]

df[metrics].mean().plot(kind="bar")

plt.title("Average Engagement Metrics")
plt.ylabel("Average COunt")
plt.show()

# %% [markdown]
# # Top 10 Posts by Saves

# %%
top_posts = df.nlargest(10, "Saves")

plt.figure(figsize = [10,5])
plt.barh(range(len(top_posts)), top_posts["Saves"])

plt.title("Top 10 Posts by Saves")
plt.xlabel("Saves")
plt.show()

# %% [markdown]
# # Saves Distribution

# %%
plt.figure(figsize = [10,5])
plt.hist(df["Saves"], bins = 15)

plt.title("Distribution of Saves")
plt.xlabel("Saves")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # Engagement Composition

# %%
likes = df["Likes"].sum()
comments = df["Comments"].sum()
shares = df["Shares"].sum()
saves = df["Saves"].sum()

plt.pie( [likes, comments, shares, saves],
         labels = ["Likes", "Comments", "Shares", "Saves"],
         autopct = "%1.1f%%"
       )
plt.title("Engagement Composition")
plt.show()

# %% [markdown]
# # Now, train a machine learning model to predict the reach of an Instagram post.

# %%
# step 1 : Let’s split the data into training and test sets before training the model:

x = np.array(df[["Likes", "Saves", "Comments", "Shares", "Profile Visits", "Follows"]])
y = np.array(df["Impressions"])

xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
# step 2 : Now here’s is how we can train a machine learning model to predict the reach of an Instagram post using Python:

model = PassiveAggressiveRegressor()
model.fit(xtrain, ytrain)
model.score(xtest, ytest)
# Out:
# 0.767770422244985

# %%
# step 3 : Now let’s predict the reach of an Instagram post by giving inputs to the machine learning model:

# Features = [['Likes','Saves', 'Comments', 'Shares', 'Profile Visits', 'Follows']]

features = np.array([[282.0, 233.0, 4.0, 9.0, 165.0, 54.0]])
model.predict(features)
# Out:
# array([10854.30649199])
